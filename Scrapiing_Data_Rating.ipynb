# %%
import requests
import csv

def get_anime_data(anime_id):
    url = f'https://api.jikan.moe/v4/anime/{anime_id}/full'
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        return None

def extract_anime_info(data):
    if not data or 'data' not in data:
        return None

    anime_data = data['data']

    def safe_get(obj, keys, default=None):
        for key in keys:
            if key in obj:
                obj = obj[key]
            else:
                return default
        return obj

    genres = safe_get(anime_data, ['genres'], [])
    genres_str = ', '.join([genre['name'] for genre in genres])

    anime_info = {
        'mal_id': safe_get(anime_data, ['mal_id']),
        'url': safe_get(anime_data, ['url']),
        'image_url': safe_get(anime_data, ['images', 'jpg', 'image_url']),
        'title': safe_get(anime_data, ['title']),
        'type': safe_get(anime_data, ['type']),
        'source': safe_get(anime_data, ['source']),
        'episodes': safe_get(anime_data, ['episodes']),
        'status': safe_get(anime_data, ['status']),
        'duration': safe_get(anime_data, ['duration']),
        'rating': safe_get(anime_data, ['rating']),
        'score': safe_get(anime_data, ['score']),
        'scored_by': safe_get(anime_data, ['scored_by']),
        'rank': safe_get(anime_data, ['rank']),
        'popularity': safe_get(anime_data, ['popularity']),
        'members': safe_get(anime_data, ['members']),
        'favorites': safe_get(anime_data, ['favorites']),
        'synopsis': safe_get(anime_data, ['synopsis']),
        'season': safe_get(anime_data, ['season']),
        'year': safe_get(anime_data, ['year']),
        'genres': genres_str
    }

    return anime_info

def save_to_csv(anime_infos, filename='anime_data.csv'):
    if not anime_infos:
        return
    keys = anime_infos[0].keys()
    with open(filename, 'w', newline='', encoding='utf-8') as output_file:
        dict_writer = csv.DictWriter(output_file, fieldnames=keys)
        dict_writer.writeheader()
        dict_writer.writerows(anime_infos)

def main():
    anime_ids = range(1, 100001)  # Range of anime IDs from 1 to 100000
    anime_infos = []

    for anime_id in anime_ids:
        data = get_anime_data(anime_id)
        anime_info = extract_anime_info(data)
        if anime_info:
            anime_infos.append(anime_info)
            print(f"Berhasil mengambil data untuk ID {anime_id}")
        else:
            print(f"Gagal mengambil data dengan ID {anime_id}")

    save_to_csv(anime_infos)

if __name__ == '__main__':
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Gagal mengambil data dengan ID 18810
# Gagal mengambil data dengan ID 18811
# Gagal mengambil data dengan ID 18812
# Gagal mengambil data dengan ID 18813
# Gagal mengambil data dengan ID 18814
# Berhasil mengambil data untuk ID 18815
# Gagal mengambil data dengan ID 18816
# Berhasil mengambil data untuk ID 18817
# Gagal mengambil data dengan ID 18818
# Berhasil mengambil data untuk ID 18819
# Gagal mengambil data dengan ID 18820
# Berhasil mengambil data untuk ID 18821
# Gagal mengambil data dengan ID 18822
# Berhasil mengambil data untuk ID 18823
# Gagal mengambil data dengan ID 18824
# Berhasil mengambil data untuk ID 18825
# Gagal mengambil data dengan ID 18826
# Berhasil mengambil data untuk ID 18827
# Gagal mengambil data dengan ID 18828
# Berhasil mengambil data untuk ID 18829
# Gagal mengambil data dengan ID 18830
# Berhasil mengambil data untuk ID 18831
# Gagal mengambil data dengan ID 18832
# Gagal mengambil data dengan ID 18833
# Gagal mengambil data dengan ID 18834
# Berhasil mengambil data untuk ID 18835
# Gagal mengambil data dengan ID 18836
# Gagal mengambil data dengan ID 18837
# Gagal mengambil data dengan ID 18838
# Gagal mengambil data dengan ID 18839
# Gagal mengambil data dengan ID 18840
# Berhasil mengambil data untuk ID 18841
# Gagal mengambil data dengan ID 18842
# Gagal mengambil data dengan ID 18843
# Gagal mengambil data dengan ID 18844
# Berhasil mengambil data untuk ID 18845
# Gagal mengambil data dengan ID 18846
# Gagal mengambil data dengan ID 18847
# Gagal mengambil data dengan ID 18848
# Berhasil mengambil data untuk ID 18849
# Gagal mengambil data dengan ID 18850
# Berhasil mengambil data untuk ID 18851
# Gagal mengambil data dengan ID 18852
# Gagal mengambil data dengan ID 18853
# Gagal mengambil data dengan ID 18854
# Gagal mengambil data dengan ID 18855
# Gagal mengambil data dengan ID 18856
# Berhasil mengambil data untuk ID 18857
# Gagal mengambil data dengan ID 18858
# Gagal mengambil data dengan ID 18859
# Gagal mengambil data dengan ID 18860
# Gagal mengambil data dengan ID 18861
# Gagal mengambil data dengan ID 18862
# Gagal mengambil data dengan ID 18863
# Gagal mengambil data dengan ID 18864
# Gagal mengambil data dengan ID 18865
# Gagal mengambil data dengan ID 18866
# Gagal mengambil data dengan ID 18867
# Gagal mengambil data dengan ID 18868
# Gagal mengambil data dengan ID 18869
# Gagal mengambil data dengan ID 18870
# Gagal mengambil data dengan ID 18871
# Gagal mengambil data dengan ID 18872
# Gagal mengambil data dengan ID 18873
# Gagal mengambil data dengan ID 18874
# Gagal mengambil data dengan ID 18875
# Gagal mengambil data dengan ID 18876
# Gagal mengambil data dengan ID 18877
# Gagal mengambil data dengan ID 18878
# Gagal mengambil data dengan ID 18879
# Gagal mengambil data dengan ID 18880
# Berhasil mengambil data untuk ID 18881
# Gagal mengambil data dengan ID 18882
# Gagal mengambil data dengan ID 18883
# Gagal mengambil data dengan ID 18884
# Gagal mengambil data dengan ID 18885
# Gagal mengambil data dengan ID 18886
# Gagal mengambil data dengan ID 18887
# Gagal mengambil data dengan ID 18888
# Gagal mengambil data dengan ID 18889
# Gagal mengambil data dengan ID 18890
# Gagal mengambil data dengan ID 18891
# Gagal mengambil data dengan ID 18892
# Berhasil mengambil data untuk ID 18893
# Gagal mengambil data dengan ID 18894
# Gagal mengambil data dengan ID 18895
# Gagal mengambil data dengan ID 18896
# Berhasil mengambil data untuk ID 18897
# Gagal mengambil data dengan ID 18898
# Gagal mengambil data dengan ID 18899
# Gagal mengambil data dengan ID 18900
# Gagal mengambil data dengan ID 18901
# Gagal mengambil data dengan ID 18902
# Gagal mengambil data dengan ID 18903
# Gagal mengambil data dengan ID 18904
# Gagal mengambil data dengan ID 18905
# Gagal mengambil data dengan ID 18906
# Berhasil mengambil data untuk ID 18907
# Gagal mengambil data dengan ID 18908
# Gagal mengambil data dengan ID 18909
# Gagal mengambil data dengan ID 18910
# Gagal mengambil data dengan ID 18911
# Gagal mengambil data dengan ID 18912
# Gagal mengambil data dengan ID 18913
# Gagal mengambil data dengan ID 18914
# Gagal mengambil data dengan ID 18915
# Gagal mengambil data dengan ID 18916
# Gagal mengambil data dengan ID 18917
# Gagal mengambil data dengan ID 18918
# Berhasil mengambil data untuk ID 18919
# Gagal mengambil data dengan ID 18920
# Gagal mengambil data dengan ID 18921
# Gagal mengambil data dengan ID 18922
# Gagal mengambil data dengan ID 18923
# Gagal mengambil data dengan ID 18924
# Gagal mengambil data dengan ID 18925
# Gagal mengambil data dengan ID 18926
# Gagal mengambil data dengan ID 18927
# Gagal mengambil data dengan ID 18928
# Gagal mengambil data dengan ID 18929
# Gagal mengambil data dengan ID 18930
# Gagal mengambil data dengan ID 18931
# Gagal mengambil data dengan ID 18932
# Gagal mengambil data dengan ID 18933
# Gagal mengambil data dengan ID 18934
# Gagal mengambil data dengan ID 18935
# Gagal mengambil data dengan ID 18936
# Berhasil mengambil data untuk ID 18937
# Gagal mengambil data dengan ID 18938
# Berhasil mengambil data untuk ID 18939
# Gagal mengambil data dengan ID 18940
# Berhasil mengambil data untuk ID 18941
# Gagal mengambil data dengan ID 18942
# Berhasil mengambil data untuk ID 18943
# Gagal mengambil data dengan ID 18944
# Gagal mengambil data dengan ID 18945
# Gagal mengambil data dengan ID 18946
# Gagal mengambil data dengan ID 18947
# Gagal mengambil data dengan ID 18948
# Gagal mengambil data dengan ID 18949
# Gagal mengambil data dengan ID 18950
# Gagal mengambil data dengan ID 18951
# Gagal mengambil data dengan ID 18952
# Berhasil mengambil data untuk ID 18953
# Gagal mengambil data dengan ID 18954
# Gagal mengambil data dengan ID 18955
# Gagal mengambil data dengan ID 18956
# Gagal mengambil data dengan ID 18957
# Gagal mengambil data dengan ID 18958
# Berhasil mengambil data untuk ID 18959
# Gagal mengambil data dengan ID 18960
# Gagal mengambil data dengan ID 18961
# Gagal mengambil data dengan ID 18962
# Gagal mengambil data dengan ID 18963
# Gagal mengambil data dengan ID 18964
# Gagal mengambil data dengan ID 18965
# Gagal mengambil data dengan ID 18966
# Berhasil mengambil data untuk ID 18967
# Gagal mengambil data dengan ID 18968
# Gagal mengambil data dengan ID 18969
# Gagal mengambil data dengan ID 18970
# Gagal mengambil data dengan ID 18971
# Gagal mengambil data dengan ID 18972
# Gagal mengambil data dengan ID 18973
# Gagal mengambil data dengan ID 18974
# Gagal mengambil data dengan ID 18975
# Gagal mengambil data dengan ID 18976
# Gagal mengambil data dengan ID 18977
# Gagal mengambil data dengan ID 18978
# Gagal mengambil data dengan ID 18979
# Gagal mengambil data dengan ID 18980
# Gagal mengambil data dengan ID 18981
# Gagal mengambil data dengan ID 18982
# Berhasil mengambil data untuk ID 18983
# Gagal mengambil data dengan ID 18984
# Gagal mengambil data dengan ID 18985
# Gagal mengambil data dengan ID 18986
# Gagal mengambil data dengan ID 18987
# Gagal mengambil data dengan ID 18988
# Berhasil mengambil data untuk ID 18989
# Gagal mengambil data dengan ID 18990
# Gagal mengambil data dengan ID 18991
# Gagal mengambil data dengan ID 18992
# Gagal mengambil data dengan ID 18993
# Gagal mengambil data dengan ID 18994
# Gagal mengambil data dengan ID 18995
# Gagal mengambil data dengan ID 18996
# Gagal mengambil data dengan ID 18997
# Gagal mengambil data dengan ID 18998
# Gagal mengambil data dengan ID 18999
# Gagal mengambil data dengan ID 19000
# Gagal mengambil data dengan ID 19001
# Gagal mengambil data dengan ID 19002
# Gagal mengambil data dengan ID 19003
# Gagal mengambil data dengan ID 19004
# Gagal mengambil data dengan ID 19005
# Gagal mengambil data dengan ID 19006
# Gagal mengambil data dengan ID 19007
# Gagal mengambil data dengan ID 19008
# Berhasil mengambil data untuk ID 19009
# Gagal mengambil data dengan ID 19010
# Gagal mengambil data dengan ID 19011
# Gagal mengambil data dengan ID 19012
# Gagal mengambil data dengan ID 19013
# Gagal mengambil data dengan ID 19014
# Gagal mengambil data dengan ID 19015
# Gagal mengambil data dengan ID 19016
# Gagal mengambil data dengan ID 19017
# Gagal mengambil data dengan ID 19018
# Gagal mengambil data dengan ID 19019
# Gagal mengambil data dengan ID 19020
# Berhasil mengambil data untuk ID 19021
# Gagal mengambil data dengan ID 19022
# Berhasil mengambil data untuk ID 19023
# Gagal mengambil data dengan ID 19024
# Gagal mengambil data dengan ID 19025
# Gagal mengambil data dengan ID 19026
# Gagal mengambil data dengan ID 19027
# Gagal mengambil data dengan ID 19028
# Berhasil mengambil data untuk ID 19029
# Gagal mengambil data dengan ID 19030
# Gagal mengambil data dengan ID 19031
# Gagal mengambil data dengan ID 19032
# Gagal mengambil data dengan ID 19033
# Gagal mengambil data dengan ID 19034
# Gagal mengambil data dengan ID 19035
# Gagal mengambil data dengan ID 19036
# Gagal mengambil data dengan ID 19037
# Gagal mengambil data dengan ID 19038
# Gagal mengambil data dengan ID 19039
# Gagal mengambil data dengan ID 19040
# Gagal mengambil data dengan ID 19041
# Gagal mengambil data dengan ID 19042
# Gagal mengambil data dengan ID 19043
# Gagal mengambil data dengan ID 19044
# Gagal mengambil data dengan ID 19045
# Gagal mengambil data dengan ID 19046
# Gagal mengambil data dengan ID 19047
# Gagal mengambil data dengan ID 19048
# Berhasil mengambil data untuk ID 19049
# Gagal mengambil data dengan ID 19050
# Berhasil mengambil data untuk ID 19051
# Gagal mengambil data dengan ID 19052
# Berhasil mengambil data untuk ID 19053
# Gagal mengambil data dengan ID 19054
# Gagal mengambil data dengan ID 19055
# Gagal mengambil data dengan ID 19056
# Gagal mengambil data dengan ID 19057
# Gagal mengambil data dengan ID 19058
# Berhasil mengambil data untuk ID 19059
# Gagal mengambil data dengan ID 19060
# Gagal mengambil data dengan ID 19061
# Gagal mengambil data dengan ID 19062
# Berhasil mengambil data untuk ID 19063
# Gagal mengambil data dengan ID 19064
# Gagal mengambil data dengan ID 19065
# Gagal mengambil data dengan ID 19066
# Berhasil mengambil data untuk ID 19067
# Gagal mengambil data dengan ID 19068
# Berhasil mengambil data untuk ID 19069
# Gagal mengambil data dengan ID 19070
# Berhasil mengambil data untuk ID 19071
# Gagal mengambil data dengan ID 19072
# Berhasil mengambil data untuk ID 19073
# Gagal mengambil data dengan ID 19074
# Gagal mengambil data dengan ID 19075
# Gagal mengambil data dengan ID 19076
# Gagal mengambil data dengan ID 19077
# Gagal mengambil data dengan ID 19078
# Gagal mengambil data dengan ID 19079
# Gagal mengambil data dengan ID 19080
# Berhasil mengambil data untuk ID 19081
# Gagal mengambil data dengan ID 19082
# Gagal mengambil data dengan ID 19083
# Gagal mengambil data dengan ID 19084
# Gagal mengambil data dengan ID 19085
# Gagal mengambil data dengan ID 19086
# Berhasil mengambil data untuk ID 19087
# Gagal mengambil data dengan ID 19088
# Gagal mengambil data dengan ID 19089
# Gagal mengambil data dengan ID 19090
# Gagal mengambil data dengan ID 19091
# Gagal mengambil data dengan ID 19092
# Gagal mengambil data dengan ID 19093
# Gagal mengambil data dengan ID 19094
# Gagal mengambil data dengan ID 19095
# Gagal mengambil data dengan ID 19096
# Gagal mengambil data dengan ID 19097
# Gagal mengambil data dengan ID 19098
# Berhasil mengambil data untuk ID 19099
# Gagal mengambil data dengan ID 19100
# Berhasil mengambil data untuk ID 19101
# Gagal mengambil data dengan ID 19102
# Berhasil mengambil data untuk ID 19103
# Gagal mengambil data dengan ID 19104
# Gagal mengambil data dengan ID 19105
# Gagal mengambil data dengan ID 19106
# Gagal mengambil data dengan ID 19107
# Gagal mengambil data dengan ID 19108
# Berhasil mengambil data untuk ID 19109
# Gagal mengambil data dengan ID 19110
# Berhasil mengambil data untuk ID 19111
# Gagal mengambil data dengan ID 19112
# Gagal mengambil data dengan ID 19113
# Gagal mengambil data dengan ID 19114
# Berhasil mengambil data untuk ID 19115
# Gagal mengambil data dengan ID 19116
# Berhasil mengambil data untuk ID 19117
# Gagal mengambil data dengan ID 19118
# Gagal mengambil data dengan ID 19119
# Gagal mengambil data dengan ID 19120
# Berhasil mengambil data untuk ID 19121
# Gagal mengambil data dengan ID 19122
# Berhasil mengambil data untuk ID 19123
# Gagal mengambil data dengan ID 19124
# Berhasil mengambil data untuk ID 19125
# Gagal mengambil data dengan ID 19126
# Gagal mengambil data dengan ID 19127
# Gagal mengambil data dengan ID 19128
# Gagal mengambil data dengan ID 19129
# Gagal mengambil data dengan ID 19130
# Gagal mengambil data dengan ID 19131
# Gagal mengambil data dengan ID 19132
# Berhasil mengambil data untuk ID 19133
# Gagal mengambil data dengan ID 19134
# Berhasil mengambil data untuk ID 19135
# Gagal mengambil data dengan ID 19136
# Berhasil mengambil data untuk ID 19137
# Gagal mengambil data dengan ID 19138
# Gagal mengambil data dengan ID 19139
# Gagal mengambil data dengan ID 19140
# Gagal mengambil data dengan ID 19141
# Gagal mengambil data dengan ID 19142
# Gagal mengambil data dengan ID 19143
# Gagal mengambil data dengan ID 19144
# Gagal mengambil data dengan ID 19145
# Gagal mengambil data dengan ID 19146
# Gagal mengambil data dengan ID 19147
# Gagal mengambil data dengan ID 19148
# Gagal mengambil data dengan ID 19149
# Gagal mengambil data dengan ID 19150
# Berhasil mengambil data untuk ID 19151
# Gagal mengambil data dengan ID 19152
# Gagal mengambil data dengan ID 19153
# Gagal mengambil data dengan ID 19154
# Gagal mengambil data dengan ID 19155
# Gagal mengambil data dengan ID 19156
# Berhasil mengambil data untuk ID 19157
# Gagal mengambil data dengan ID 19158
# Berhasil mengambil data untuk ID 19159
# Gagal mengambil data dengan ID 19160
# Gagal mengambil data dengan ID 19161
# Gagal mengambil data dengan ID 19162
# Berhasil mengambil data untuk ID 19163
# Gagal mengambil data dengan ID 19164
# Berhasil mengambil data untuk ID 19165
# Gagal mengambil data dengan ID 19166
# Berhasil mengambil data untuk ID 19167
# Gagal mengambil data dengan ID 19168
# Berhasil mengambil data untuk ID 19169
# Gagal mengambil data dengan ID 19170
# Berhasil mengambil data untuk ID 19171
# Gagal mengambil data dengan ID 19172
# Gagal mengambil data dengan ID 19173
# Gagal mengambil data dengan ID 19174
# Gagal mengambil data dengan ID 19175
# Gagal mengambil data dengan ID 19176
# Berhasil mengambil data untuk ID 19177
# Gagal mengambil data dengan ID 19178
# Gagal mengambil data dengan ID 19179
# Gagal mengambil data dengan ID 19180
# Gagal mengambil data dengan ID 19181
# Gagal mengambil data dengan ID 19182
# Gagal mengambil data dengan ID 19183
# Gagal mengambil data dengan ID 19184
# Berhasil mengambil data untuk ID 19185
# Gagal mengambil data dengan ID 19186
# Berhasil mengambil data untuk ID 19187
# Gagal mengambil data dengan ID 19188
# Gagal mengambil data dengan ID 19189
# Gagal mengambil data dengan ID 19190
# Berhasil mengambil data untuk ID 19191
# Gagal mengambil data dengan ID 19192
# Berhasil mengambil data untuk ID 19193
# Gagal mengambil data dengan ID 19194
# Berhasil mengambil data untuk ID 19195
# Gagal mengambil data dengan ID 19196
# Gagal mengambil data dengan ID 19197
# Gagal mengambil data dengan ID 19198
# Gagal mengambil data dengan ID 19199
# Gagal mengambil data dengan ID 19200
# Gagal mengambil data dengan ID 19201
# Gagal mengambil data dengan ID 19202
# Gagal mengambil data dengan ID 19203
# Gagal mengambil data dengan ID 19204
# Gagal mengambil data dengan ID 19205
# Gagal mengambil data dengan ID 19206
# Berhasil mengambil data untuk ID 19207
# Gagal mengambil data dengan ID 19208
# Berhasil mengambil data untuk ID 19209
# Gagal mengambil data dengan ID 19210
# Berhasil mengambil data untuk ID 19211
# Gagal mengambil data dengan ID 19212
# Berhasil mengambil data untuk ID 19213
# Gagal mengambil data dengan ID 19214
# Gagal mengambil data dengan ID 19215
# Gagal mengambil data dengan ID 19216
# Berhasil mengambil data untuk ID 19217
# Gagal mengambil data dengan ID 19218
# Berhasil mengambil data untuk ID 19219
# Gagal mengambil data dengan ID 19220
# Berhasil mengambil data untuk ID 19221
# Gagal mengambil data dengan ID 19222
# Gagal mengambil data dengan ID 19223
# Gagal mengambil data dengan ID 19224
# Gagal mengambil data dengan ID 19225
# Gagal mengambil data dengan ID 19226
# Gagal mengambil data dengan ID 19227
# Gagal mengambil data dengan ID 19228
# Gagal mengambil data dengan ID 19229
# Gagal mengambil data dengan ID 19230
# Berhasil mengambil data untuk ID 19231
# Gagal mengambil data dengan ID 19232
# Berhasil mengambil data untuk ID 19233
# Gagal mengambil data dengan ID 19234
# Berhasil mengambil data untuk ID 19235
# Gagal mengambil data dengan ID 19236
# Berhasil mengambil data untuk ID 19237
# Gagal mengambil data dengan ID 19238
# Berhasil mengambil data untuk ID 19239
# Gagal mengambil data dengan ID 19240
# Gagal mengambil data dengan ID 19241
# Gagal mengambil data dengan ID 19242
# Gagal mengambil data dengan ID 19243
# Gagal mengambil data dengan ID 19244
# Gagal mengambil data dengan ID 19245
# Gagal mengambil data dengan ID 19246
# Gagal mengambil data dengan ID 19247
# Gagal mengambil data dengan ID 19248
# Gagal mengambil data dengan ID 19249
# Gagal mengambil data dengan ID 19250
# Berhasil mengambil data untuk ID 19251
# Gagal mengambil data dengan ID 19252
# Gagal mengambil data dengan ID 19253
# Gagal mengambil data dengan ID 19254
# Berhasil mengambil data untuk ID 19255
# Gagal mengambil data dengan ID 19256
# Berhasil mengambil data untuk ID 19257
# Gagal mengambil data dengan ID 19258
# Gagal mengambil data dengan ID 19259
# Gagal mengambil data dengan ID 19260
# Berhasil mengambil data untuk ID 19261
# Gagal mengambil data dengan ID 19262
# Gagal mengambil data dengan ID 19263
# Gagal mengambil data dengan ID 19264
# Gagal mengambil data dengan ID 19265
# Gagal mengambil data dengan ID 19266
# Gagal mengambil data dengan ID 19267
# Gagal mengambil data dengan ID 19268
# Gagal mengambil data dengan ID 19269
# Gagal mengambil data dengan ID 19270
# Berhasil mengambil data untuk ID 19271
# Gagal mengambil data dengan ID 19272
# Gagal mengambil data dengan ID 19273
# Gagal mengambil data dengan ID 19274
# Gagal mengambil data dengan ID 19275
# Gagal mengambil data dengan ID 19276
# Gagal mengambil data dengan ID 19277
# Gagal mengambil data dengan ID 19278
# Berhasil mengambil data untuk ID 19279
# Gagal mengambil data dengan ID 19280
# Gagal mengambil data dengan ID 19281
# Gagal mengambil data dengan ID 19282
# Berhasil mengambil data untuk ID 19283
# Gagal mengambil data dengan ID 19284
# Berhasil mengambil data untuk ID 19285
# Gagal mengambil data dengan ID 19286
# Berhasil mengambil data untuk ID 19287
# Gagal mengambil data dengan ID 19288
# Gagal mengambil data dengan ID 19289
# Gagal mengambil data dengan ID 19290
# Berhasil mengambil data untuk ID 19291
# Gagal mengambil data dengan ID 19292
# Gagal mengambil data dengan ID 19293
# Gagal mengambil data dengan ID 19294
# Gagal mengambil data dengan ID 19295
# Gagal mengambil data dengan ID 19296
# Berhasil mengambil data untuk ID 19297
# Gagal mengambil data dengan ID 19298
# Gagal mengambil data dengan ID 19299
# Gagal mengambil data dengan ID 19300
# Gagal mengambil data dengan ID 19301
# Gagal mengambil data dengan ID 19302
# Gagal mengambil data dengan ID 19303
# Gagal mengambil data dengan ID 19304
# Berhasil mengambil data untuk ID 19305
# Gagal mengambil data dengan ID 19306
# Gagal mengambil data dengan ID 19307
# Gagal mengambil data dengan ID 19308
# Gagal mengambil data dengan ID 19309
# Gagal mengambil data dengan ID 19310
# Berhasil mengambil data untuk ID 19311
# Gagal mengambil data dengan ID 19312
# Gagal mengambil data dengan ID 19313
# Gagal mengambil data dengan ID 19314
# Berhasil mengambil data untuk ID 19315
# Gagal mengambil data dengan ID 19316
# Gagal mengambil data dengan ID 19317
# Gagal mengambil data dengan ID 19318
# Berhasil mengambil data untuk ID 19319
# Gagal mengambil data dengan ID 19320
# Gagal mengambil data dengan ID 19321
# Gagal mengambil data dengan ID 19322
# Gagal mengambil data dengan ID 19323
# Gagal mengambil data dengan ID 19324
# Berhasil mengambil data untuk ID 19325
# Gagal mengambil data dengan ID 19326
# Gagal mengambil data dengan ID 19327
# Gagal mengambil data dengan ID 19328
# Gagal mengambil data dengan ID 19329
# Gagal mengambil data dengan ID 19330
# Gagal mengambil data dengan ID 19331
# Gagal mengambil data dengan ID 19332
# Gagal mengambil data dengan ID 19333
# Gagal mengambil data dengan ID 19334
# Gagal mengambil data dengan ID 19335
# Gagal mengambil data dengan ID 19336
# Berhasil mengambil data untuk ID 19337
# Gagal mengambil data dengan ID 19338
# Gagal mengambil data dengan ID 19339
# Gagal mengambil data dengan ID 19340
# Gagal mengambil data dengan ID 19341
# Gagal mengambil data dengan ID 19342
# Gagal mengambil data dengan ID 19343
# Gagal mengambil data dengan ID 19344
# Gagal mengambil data dengan ID 19345
# Gagal mengambil data dengan ID 19346
# Gagal mengambil data dengan ID 19347
# Gagal mengambil data dengan ID 19348
# Gagal mengambil data dengan ID 19349
# Gagal mengambil data dengan ID 19350
# Berhasil mengambil data untuk ID 19351
# Gagal mengambil data dengan ID 19352
# Gagal mengambil data dengan ID 19353
# Gagal mengambil data dengan ID 19354
# Gagal mengambil data dengan ID 19355
# Gagal mengambil data dengan ID 19356
# Gagal mengambil data dengan ID 19357
# Gagal mengambil data dengan ID 19358
# Gagal mengambil data dengan ID 19359
# Gagal mengambil data dengan ID 19360
# Gagal mengambil data dengan ID 19361
# Gagal mengambil data dengan ID 19362
# Berhasil mengambil data untuk ID 19363
# Gagal mengambil data dengan ID 19364
# Berhasil mengambil data untuk ID 19365
# Gagal mengambil data dengan ID 19366
# Berhasil mengambil data untuk ID 19367
# Gagal mengambil data dengan ID 19368
# Berhasil mengambil data untuk ID 19369
# Gagal mengambil data dengan ID 19370
# Gagal mengambil data dengan ID 19371
# Gagal mengambil data dengan ID 19372
# Gagal mengambil data dengan ID 19373
# Gagal mengambil data dengan ID 19374
# Gagal mengambil data dengan ID 19375
# Gagal mengambil data dengan ID 19376
# Gagal mengambil data dengan ID 19377
# Gagal mengambil data dengan ID 19378
# Gagal mengambil data dengan ID 19379
# Gagal mengambil data dengan ID 19380
# Gagal mengambil data dengan ID 19381
# Gagal mengambil data dengan ID 19382
# Berhasil mengambil data untuk ID 19383
# Gagal mengambil data dengan ID 19384
# Gagal mengambil data dengan ID 19385
# Gagal mengambil data dengan ID 19386
# Gagal mengambil data dengan ID 19387
# Gagal mengambil data dengan ID 19388
# Gagal mengambil data dengan ID 19389
# Gagal mengambil data dengan ID 19390
# Berhasil mengambil data untuk ID 19391
# Gagal mengambil data dengan ID 19392
# Gagal mengambil data dengan ID 19393
# Gagal mengambil data dengan ID 19394
# Gagal mengambil data dengan ID 19395
# Gagal mengambil data dengan ID 19396
# Berhasil mengambil data untuk ID 19397
# Gagal mengambil data dengan ID 19398
# Gagal mengambil data dengan ID 19399
# Gagal mengambil data dengan ID 19400
# Berhasil mengambil data untuk ID 19401
# Gagal mengambil data dengan ID 19402
# Gagal mengambil data dengan ID 19403
# Gagal mengambil data dengan ID 19404
# Gagal mengambil data dengan ID 19405
# Gagal mengambil data dengan ID 19406
# Gagal mengambil data dengan ID 19407
# Gagal mengambil data dengan ID 19408
# Gagal mengambil data dengan ID 19409
# Gagal mengambil data dengan ID 19410
# Gagal mengambil data dengan ID 19411
# Gagal mengambil data dengan ID 19412
# Gagal mengambil data dengan ID 19413
# Gagal mengambil data dengan ID 19414
# Gagal mengambil data dengan ID 19415
# Gagal mengambil data dengan ID 19416
# Gagal mengambil data dengan ID 19417
# Gagal mengambil data dengan ID 19418
# Gagal mengambil data dengan ID 19419
# Gagal mengambil data dengan ID 19420
# Gagal mengambil data dengan ID 19421
# Gagal mengambil data dengan ID 19422
# Gagal mengambil data dengan ID 19423
# Gagal mengambil data dengan ID 19424
# Gagal mengambil data dengan ID 19425
# Gagal mengambil data dengan ID 19426
# Gagal mengambil data dengan ID 19427
# Gagal mengambil data dengan ID 19428
# Berhasil mengambil data untuk ID 19429
# Gagal mengambil data dengan ID 19430
# Berhasil mengambil data untuk ID 19431
# Gagal mengambil data dengan ID 19432
# Berhasil mengambil data untuk ID 19433
# Gagal mengambil data dengan ID 19434
# Gagal mengambil data dengan ID 19435
# Gagal mengambil data dengan ID 19436
# Berhasil mengambil data untuk ID 19437
# Gagal mengambil data dengan ID 19438
# Gagal mengambil data dengan ID 19439
# Gagal mengambil data dengan ID 19440
# Gagal mengambil data dengan ID 19441
# Gagal mengambil data dengan ID 19442
# Gagal mengambil data dengan ID 19443
# Gagal mengambil data dengan ID 19444
# Berhasil mengambil data untuk ID 19445
# Gagal mengambil data dengan ID 19446
# Berhasil mengambil data untuk ID 19447
# Gagal mengambil data dengan ID 19448
# Gagal mengambil data dengan ID 19449
# Gagal mengambil data dengan ID 19450
# Gagal mengambil data dengan ID 19451
# Gagal mengambil data dengan ID 19452
# Gagal mengambil data dengan ID 19453
# Gagal mengambil data dengan ID 19454
# Gagal mengambil data dengan ID 19455
# Gagal mengambil data dengan ID 19456
# Berhasil mengambil data untuk ID 19457
# Gagal mengambil data dengan ID 19458
# Gagal mengambil data dengan ID 19459
# Gagal mengambil data dengan ID 19460
# Gagal mengambil data dengan ID 19461
# Gagal mengambil data dengan ID 19462
# Berhasil mengambil data untuk ID 19463
# Gagal mengambil data dengan ID 19464
# Gagal mengambil data dengan ID 19465
# Gagal mengambil data dengan ID 19466
# Berhasil mengambil data untuk ID 19467
# Gagal mengambil data dengan ID 19468
# Berhasil mengambil data untuk ID 19469
# Gagal mengambil data dengan ID 19470
# Gagal mengambil data dengan ID 19471
# Gagal mengambil data dengan ID 19472
# Gagal mengambil data dengan ID 19473
# Gagal mengambil data dengan ID 19474
# Gagal mengambil data dengan ID 19475
# Gagal mengambil data dengan ID 19476
# Gagal mengambil data dengan ID 19477
# Gagal mengambil data dengan ID 19478
# Berhasil mengambil data untuk ID 19479
# Gagal mengambil data dengan ID 19480
# Berhasil mengambil data untuk ID 19481
# Gagal mengambil data dengan ID 19482
# Gagal mengambil data dengan ID 19483
# Gagal mengambil data dengan ID 19484
# Gagal mengambil data dengan ID 19485
# Gagal mengambil data dengan ID 19486
# Gagal mengambil data dengan ID 19487
# Gagal mengambil data dengan ID 19488
# Berhasil mengambil data untuk ID 19489
# Gagal mengambil data dengan ID 19490
# Gagal mengambil data dengan ID 19491
# Gagal mengambil data dengan ID 19492
# Gagal mengambil data dengan ID 19493
# Gagal mengambil data dengan ID 19494
# Berhasil mengambil data untuk ID 19495
# Gagal mengambil data dengan ID 19496
# Berhasil mengambil data untuk ID 19497
# Gagal mengambil data dengan ID 19498
# Gagal mengambil data dengan ID 19499
# Gagal mengambil data dengan ID 19500
# Berhasil mengambil data untuk ID 19501
# Gagal mengambil data dengan ID 19502
# Gagal mengambil data dengan ID 19503
# Gagal mengambil data dengan ID 19504
# Berhasil mengambil data untuk ID 19505
# Gagal mengambil data dengan ID 19506
# Gagal mengambil data dengan ID 19507
# Gagal mengambil data dengan ID 19508
# Gagal mengambil data dengan ID 19509
# Gagal mengambil data dengan ID 19510
# Berhasil mengambil data untuk ID 19511
# Gagal mengambil data dengan ID 19512
# Berhasil mengambil data untuk ID 19513
# Gagal mengambil data dengan ID 19514
# Berhasil mengambil data untuk ID 19515
# Gagal mengambil data dengan ID 19516
# Berhasil mengambil data untuk ID 19517
# Gagal mengambil data dengan ID 19518
# Berhasil mengambil data untuk ID 19519
# Gagal mengambil data dengan ID 19520
# Berhasil mengambil data untuk ID 19521
# Gagal mengambil data dengan ID 19522
# Berhasil mengambil data untuk ID 19523
# Gagal mengambil data dengan ID 19524
# Gagal mengambil data dengan ID 19525
# Gagal mengambil data dengan ID 19526
# Gagal mengambil data dengan ID 19527
# Gagal mengambil data dengan ID 19528
# Gagal mengambil data dengan ID 19529
# Gagal mengambil data dengan ID 19530
# Gagal mengambil data dengan ID 19531
# Gagal mengambil data dengan ID 19532
# Berhasil mengambil data untuk ID 19533
# Gagal mengambil data dengan ID 19534
# Berhasil mengambil data untuk ID 19535
# Gagal mengambil data dengan ID 19536
# Gagal mengambil data dengan ID 19537
# Gagal mengambil data dengan ID 19538
# Gagal mengambil data dengan ID 19539
# Gagal mengambil data dengan ID 19540
# Gagal mengambil data dengan ID 19541
# Gagal mengambil data dengan ID 19542
# Gagal mengambil data dengan ID 19543
# Gagal mengambil data dengan ID 19544
# Gagal mengambil data dengan ID 19545
# Gagal mengambil data dengan ID 19546
# Berhasil mengambil data untuk ID 19547
# Gagal mengambil data dengan ID 19548
# Gagal mengambil data dengan ID 19549
# Gagal mengambil data dengan ID 19550
# Gagal mengambil data dengan ID 19551
# Gagal mengambil data dengan ID 19552
# Gagal mengambil data dengan ID 19553
# Gagal mengambil data dengan ID 19554
# Berhasil mengambil data untuk ID 19555
# Gagal mengambil data dengan ID 19556
# Berhasil mengambil data untuk ID 19557
# Gagal mengambil data dengan ID 19558
# Berhasil mengambil data untuk ID 19559
# Gagal mengambil data dengan ID 19560
# Gagal mengambil data dengan ID 19561
# Gagal mengambil data dengan ID 19562
# Gagal mengambil data dengan ID 19563
# Gagal mengambil data dengan ID 19564
# Gagal mengambil data dengan ID 19565
# Gagal mengambil data dengan ID 19566
# Gagal mengambil data dengan ID 19567
# Gagal mengambil data dengan ID 19568
# Berhasil mengambil data untuk ID 19569
# Gagal mengambil data dengan ID 19570
# Gagal mengambil data dengan ID 19571
# Gagal mengambil data dengan ID 19572
# Berhasil mengambil data untuk ID 19573
# Gagal mengambil data dengan ID 19574
# Berhasil mengambil data untuk ID 19575
# Gagal mengambil data dengan ID 19576
# Gagal mengambil data dengan ID 19577
# Gagal mengambil data dengan ID 19578
# Gagal mengambil data dengan ID 19579
# Gagal mengambil data dengan ID 19580
# Berhasil mengambil data untuk ID 19581
# Gagal mengambil data dengan ID 19582
# Berhasil mengambil data untuk ID 19583
# Gagal mengambil data dengan ID 19584
# Berhasil mengambil data untuk ID 19585
# Gagal mengambil data dengan ID 19586
# Berhasil mengambil data untuk ID 19587
# Gagal mengambil data dengan ID 19588
# Gagal mengambil data dengan ID 19589
# Gagal mengambil data dengan ID 19590
# Gagal mengambil data dengan ID 19591
# Gagal mengambil data dengan ID 19592
# Gagal mengambil data dengan ID 19593
# Gagal mengambil data dengan ID 19594
# Gagal mengambil data dengan ID 19595
# Gagal mengambil data dengan ID 19596
# Berhasil mengambil data untuk ID 19597
# Gagal mengambil data dengan ID 19598
# Gagal mengambil data dengan ID 19599
# Gagal mengambil data dengan ID 19600
# Gagal mengambil data dengan ID 19601
# Gagal mengambil data dengan ID 19602
# Gagal mengambil data dengan ID 19603
# Gagal mengambil data dengan ID 19604
# Gagal mengambil data dengan ID 19605
# Gagal mengambil data dengan ID 19606
# Gagal mengambil data dengan ID 19607
# Gagal mengambil data dengan ID 19608
# Gagal mengambil data dengan ID 19609
# Gagal mengambil data dengan ID 19610
# Gagal mengambil data dengan ID 19611
# Gagal mengambil data dengan ID 19612
# Berhasil mengambil data untuk ID 19613
# Gagal mengambil data dengan ID 19614
# Gagal mengambil data dengan ID 19615
# Gagal mengambil data dengan ID 19616
# Gagal mengambil data dengan ID 19617
# Gagal mengambil data dengan ID 19618
# Berhasil mengambil data untuk ID 19619
# Gagal mengambil data dengan ID 19620
# Gagal mengambil data dengan ID 19621
# Gagal mengambil data dengan ID 19622
# Gagal mengambil data dengan ID 19623
# Gagal mengambil data dengan ID 19624
# Gagal mengambil data dengan ID 19625
# Gagal mengambil data dengan ID 19626
# Berhasil mengambil data untuk ID 19627
# Gagal mengambil data dengan ID 19628
# Berhasil mengambil data untuk ID 19629
# Gagal mengambil data dengan ID 19630
# Berhasil mengambil data untuk ID 19631
# Gagal mengambil data dengan ID 19632
# Berhasil mengambil data untuk ID 19633
# Gagal mengambil data dengan ID 19634
# Berhasil mengambil data untuk ID 19635
# Gagal mengambil data dengan ID 19636
# Gagal mengambil data dengan ID 19637
# Gagal mengambil data dengan ID 19638
# Gagal mengambil data dengan ID 19639
# Gagal mengambil data dengan ID 19640
# Gagal mengambil data dengan ID 19641
# Gagal mengambil data dengan ID 19642
# Gagal mengambil data dengan ID 19643
# Gagal mengambil data dengan ID 19644
# Berhasil mengambil data untuk ID 19645
# Gagal mengambil data dengan ID 19646
# Berhasil mengambil data untuk ID 19647
# Gagal mengambil data dengan ID 19648
# Gagal mengambil data dengan ID 19649
# Gagal mengambil data dengan ID 19650
# Gagal mengambil data dengan ID 19651
# Gagal mengambil data dengan ID 19652
# Berhasil mengambil data untuk ID 19653
# Gagal mengambil data dengan ID 19654
# Gagal mengambil data dengan ID 19655
# Gagal mengambil data dengan ID 19656
# Gagal mengambil data dengan ID 19657
# Gagal mengambil data dengan ID 19658
# Gagal mengambil data dengan ID 19659
# Gagal mengambil data dengan ID 19660
# Gagal mengambil data dengan ID 19661
# Gagal mengambil data dengan ID 19662
# Gagal mengambil data dengan ID 19663
# Gagal mengambil data dengan ID 19664
# Gagal mengambil data dengan ID 19665
# Gagal mengambil data dengan ID 19666
# Gagal mengambil data dengan ID 19667
# Gagal mengambil data dengan ID 19668
# Berhasil mengambil data untuk ID 19669
# Gagal mengambil data dengan ID 19670
# Berhasil mengambil data untuk ID 19671
# Gagal mengambil data dengan ID 19672
# Gagal mengambil data dengan ID 19673
# Gagal mengambil data dengan ID 19674
# Gagal mengambil data dengan ID 19675
# Gagal mengambil data dengan ID 19676
# Gagal mengambil data dengan ID 19677
# Gagal mengambil data dengan ID 19678
# Gagal mengambil data dengan ID 19679
# Gagal mengambil data dengan ID 19680
# Berhasil mengambil data untuk ID 19681
# Gagal mengambil data dengan ID 19682
# Gagal mengambil data dengan ID 19683
# Gagal mengambil data dengan ID 19684
# Berhasil mengambil data untuk ID 19685
# Gagal mengambil data dengan ID 19686
# Berhasil mengambil data untuk ID 19687
# Gagal mengambil data dengan ID 19688
# Gagal mengambil data dengan ID 19689
# Gagal mengambil data dengan ID 19690
# Gagal mengambil data dengan ID 19691
# Gagal mengambil data dengan ID 19692
# Gagal mengambil data dengan ID 19693
# Gagal mengambil data dengan ID 19694
# Berhasil mengambil data untuk ID 19695
# Gagal mengambil data dengan ID 19696
# Berhasil mengambil data untuk ID 19697
# Gagal mengambil data dengan ID 19698
# Gagal mengambil data dengan ID 19699
# Gagal mengambil data dengan ID 19700
# Gagal mengambil data dengan ID 19701
# Gagal mengambil data dengan ID 19702
# Berhasil mengambil data untuk ID 19703
# Gagal mengambil data dengan ID 19704
# Berhasil mengambil data untuk ID 19705
# Gagal mengambil data dengan ID 19706
# Gagal mengambil data dengan ID 19707
# Gagal mengambil data dengan ID 19708
# Gagal mengambil data dengan ID 19709
# Gagal mengambil data dengan ID 19710
# Gagal mengambil data dengan ID 19711
# Gagal mengambil data dengan ID 19712
# Gagal mengambil data dengan ID 19713
# Gagal mengambil data dengan ID 19714
# Gagal mengambil data dengan ID 19715
# Gagal mengambil data dengan ID 19716
# Berhasil mengambil data untuk ID 19717
# Gagal mengambil data dengan ID 19718
# Gagal mengambil data dengan ID 19719
# Gagal mengambil data dengan ID 19720
# Gagal mengambil data dengan ID 19721
# Gagal mengambil data dengan ID 19722
# Gagal mengambil data dengan ID 19723
# Gagal mengambil data dengan ID 19724
# Gagal mengambil data dengan ID 19725
# Gagal mengambil data dengan ID 19726
# Berhasil mengambil data untuk ID 19727
# Gagal mengambil data dengan ID 19728
# Berhasil mengambil data untuk ID 19729
# Gagal mengambil data dengan ID 19730
# Berhasil mengambil data untuk ID 19731
# Gagal mengambil data dengan ID 19732
# Gagal mengambil data dengan ID 19733
# Gagal mengambil data dengan ID 19734
# Gagal mengambil data dengan ID 19735
# Gagal mengambil data dengan ID 19736
# Gagal mengambil data dengan ID 19737
# Gagal mengambil data dengan ID 19738
# Gagal mengambil data dengan ID 19739
# Gagal mengambil data dengan ID 19740
# Gagal mengambil data dengan ID 19741
# Gagal mengambil data dengan ID 19742
# Gagal mengambil data dengan ID 19743
# Gagal mengambil data dengan ID 19744
# Berhasil mengambil data untuk ID 19745
# Gagal mengambil data dengan ID 19746
# Berhasil mengambil data untuk ID 19747
# Gagal mengambil data dengan ID 19748
# Berhasil mengambil data untuk ID 19749
# Gagal mengambil data dengan ID 19750
# Berhasil mengambil data untuk ID 19751
# Gagal mengambil data dengan ID 19752
# Berhasil mengambil data untuk ID 19753
# Gagal mengambil data dengan ID 19754
# Berhasil mengambil data untuk ID 19755
# Gagal mengambil data dengan ID 19756
# Gagal mengambil data dengan ID 19757
# Gagal mengambil data dengan ID 19758
# Berhasil mengambil data untuk ID 19759
# Gagal mengambil data dengan ID 19760
# Gagal mengambil data dengan ID 19761
# Gagal mengambil data dengan ID 19762
# Gagal mengambil data dengan ID 19763
# Gagal mengambil data dengan ID 19764
# Gagal mengambil data dengan ID 19765
# Gagal mengambil data dengan ID 19766
# Gagal mengambil data dengan ID 19767
# Gagal mengambil data dengan ID 19768
# Berhasil mengambil data untuk ID 19769
# Gagal mengambil data dengan ID 19770
# Gagal mengambil data dengan ID 19771
# Gagal mengambil data dengan ID 19772
# Berhasil mengambil data untuk ID 19773
# Gagal mengambil data dengan ID 19774
# Berhasil mengambil data untuk ID 19775
# Gagal mengambil data dengan ID 19776
# Gagal mengambil data dengan ID 19777
# Gagal mengambil data dengan ID 19778
# Gagal mengambil data dengan ID 19779
# Gagal mengambil data dengan ID 19780
# Berhasil mengambil data untuk ID 19781
# Gagal mengambil data dengan ID 19782
# Berhasil mengambil data untuk ID 19783
# Gagal mengambil data dengan ID 19784
# Gagal mengambil data dengan ID 19785
# Gagal mengambil data dengan ID 19786
# Gagal mengambil data dengan ID 19787
# Gagal mengambil data dengan ID 19788
# Gagal mengambil data dengan ID 19789
# Gagal mengambil data dengan ID 19790
# Gagal mengambil data dengan ID 19791
# Gagal mengambil data dengan ID 19792
# Gagal mengambil data dengan ID 19793
# Gagal mengambil data dengan ID 19794
# Gagal mengambil data dengan ID 19795
# Gagal mengambil data dengan ID 19796
# Gagal mengambil data dengan ID 19797
# Gagal mengambil data dengan ID 19798
# Berhasil mengambil data untuk ID 19799
# Gagal mengambil data dengan ID 19800
# Gagal mengambil data dengan ID 19801
# Gagal mengambil data dengan ID 19802
# Gagal mengambil data dengan ID 19803
# Gagal mengambil data dengan ID 19804
# Gagal mengambil data dengan ID 19805
# Gagal mengambil data dengan ID 19806
# Gagal mengambil data dengan ID 19807
# Gagal mengambil data dengan ID 19808
# Gagal mengambil data dengan ID 19809
# Gagal mengambil data dengan ID 19810
# Berhasil mengambil data untuk ID 19811
# Gagal mengambil data dengan ID 19812
# Gagal mengambil data dengan ID 19813
# Gagal mengambil data dengan ID 19814
# Berhasil mengambil data untuk ID 19815
# Gagal mengambil data dengan ID 19816
# Berhasil mengambil data untuk ID 19817
# Gagal mengambil data dengan ID 19818
# Gagal mengambil data dengan ID 19819
# Gagal mengambil data dengan ID 19820
# Gagal mengambil data dengan ID 19821
# Gagal mengambil data dengan ID 19822
# Gagal mengambil data dengan ID 19823
# Gagal mengambil data dengan ID 19824
# Berhasil mengambil data untuk ID 19825
# Gagal mengambil data dengan ID 19826
# Gagal mengambil data dengan ID 19827
# Gagal mengambil data dengan ID 19828
# Gagal mengambil data dengan ID 19829
# Gagal mengambil data dengan ID 19830
# Berhasil mengambil data untuk ID 19831
# Gagal mengambil data dengan ID 19832
# Gagal mengambil data dengan ID 19833
# Gagal mengambil data dengan ID 19834
# Gagal mengambil data dengan ID 19835
# Gagal mengambil data dengan ID 19836
# Gagal mengambil data dengan ID 19837
# Gagal mengambil data dengan ID 19838
# Berhasil mengambil data untuk ID 19839
# Gagal mengambil data dengan ID 19840
# Berhasil mengambil data untuk ID 19841
# Gagal mengambil data dengan ID 19842
# Berhasil mengambil data untuk ID 19843
# Gagal mengambil data dengan ID 19844
# Berhasil mengambil data untuk ID 19845
# Gagal mengambil data dengan ID 19846
# Gagal mengambil data dengan ID 19847
# Gagal mengambil data dengan ID 19848
# Berhasil mengambil data untuk ID 19849
# Gagal mengambil data dengan ID 19850
# Gagal mengambil data dengan ID 19851
# Gagal mengambil data dengan ID 19852
# Gagal mengambil data dengan ID 19853
# Gagal mengambil data dengan ID 19854
# Berhasil mengambil data untuk ID 19855
# Gagal mengambil data dengan ID 19856
# Berhasil mengambil data untuk ID 19857
# Gagal mengambil data dengan ID 19858
# Berhasil mengambil data untuk ID 19859
# Gagal mengambil data dengan ID 19860
# Gagal mengambil data dengan ID 19861
# Gagal mengambil data dengan ID 19862
# Gagal mengambil data dengan ID 19863
# Gagal mengambil data dengan ID 19864
# Gagal mengambil data dengan ID 19865
# Gagal mengambil data dengan ID 19866
# Gagal mengambil data dengan ID 19867
# Gagal mengambil data dengan ID 19868
# Gagal mengambil data dengan ID 19869
# Gagal mengambil data dengan ID 19870
# Berhasil mengambil data untuk ID 19871
# Gagal mengambil data dengan ID 19872
# Berhasil mengambil data untuk ID 19873
# Gagal mengambil data dengan ID 19874
# Berhasil mengambil data untuk ID 19875
# Gagal mengambil data dengan ID 19876
# Berhasil mengambil data untuk ID 19877
# Gagal mengambil data dengan ID 19878
# Berhasil mengambil data untuk ID 19879
# Gagal mengambil data dengan ID 19880
# Gagal mengambil data dengan ID 19881
# Gagal mengambil data dengan ID 19882
# Gagal mengambil data dengan ID 19883
# Gagal mengambil data dengan ID 19884
# Gagal mengambil data dengan ID 19885
# Gagal mengambil data dengan ID 19886
# Berhasil mengambil data untuk ID 19887
# Gagal mengambil data dengan ID 19888
# Berhasil mengambil data untuk ID 19889
# Gagal mengambil data dengan ID 19890
# Gagal mengambil data dengan ID 19891
# Gagal mengambil data dengan ID 19892
# Gagal mengambil data dengan ID 19893
# Gagal mengambil data dengan ID 19894
# Gagal mengambil data dengan ID 19895
# Gagal mengambil data dengan ID 19896
# Berhasil mengambil data untuk ID 19897
# Gagal mengambil data dengan ID 19898
# Berhasil mengambil data untuk ID 19899
# Gagal mengambil data dengan ID 19900
# Berhasil mengambil data untuk ID 19901
# Gagal mengambil data dengan ID 19902
# Gagal mengambil data dengan ID 19903
# Gagal mengambil data dengan ID 19904
# Berhasil mengambil data untuk ID 19905
# Gagal mengambil data dengan ID 19906
# Berhasil mengambil data untuk ID 19907
# Gagal mengambil data dengan ID 19908
# Berhasil mengambil data untuk ID 19909
# Gagal mengambil data dengan ID 19910
# Gagal mengambil data dengan ID 19911
# Gagal mengambil data dengan ID 19912
# Gagal mengambil data dengan ID 19913
# Gagal mengambil data dengan ID 19914
# Gagal mengambil data dengan ID 19915
# Gagal mengambil data dengan ID 19916
# Berhasil mengambil data untuk ID 19917
# Gagal mengambil data dengan ID 19918
# Berhasil mengambil data untuk ID 19919
# Gagal mengambil data dengan ID 19920
# Berhasil mengambil data untuk ID 19921
# Gagal mengambil data dengan ID 19922
# Berhasil mengambil data untuk ID 19923
# Gagal mengambil data dengan ID 19924
# Berhasil mengambil data untuk ID 19925
# Gagal mengambil data dengan ID 19926
# Gagal mengambil data dengan ID 19927
# Gagal mengambil data dengan ID 19928
# Gagal mengambil data dengan ID 19929
# Gagal mengambil data dengan ID 19930
# Gagal mengambil data dengan ID 19931
# Gagal mengambil data dengan ID 19932
# Gagal mengambil data dengan ID 19933
# Gagal mengambil data dengan ID 19934
# Gagal mengambil data dengan ID 19935
# Gagal mengambil data dengan ID 19936
# Gagal mengambil data dengan ID 19937
# Gagal mengambil data dengan ID 19938
# Gagal mengambil data dengan ID 19939
# Gagal mengambil data dengan ID 19940
# Berhasil mengambil data untuk ID 19941
# Gagal mengambil data dengan ID 19942
# Berhasil mengambil data untuk ID 19943
# Gagal mengambil data dengan ID 19944
# Berhasil mengambil data untuk ID 19945
# Gagal mengambil data dengan ID 19946
# Berhasil mengambil data untuk ID 19947
# Gagal mengambil data dengan ID 19948
# Gagal mengambil data dengan ID 19949
# Gagal mengambil data dengan ID 19950
# Berhasil mengambil data untuk ID 19951
# Gagal mengambil data dengan ID 19952
# Berhasil mengambil data untuk ID 19953
# Gagal mengambil data dengan ID 19954
# Gagal mengambil data dengan ID 19955
# Gagal mengambil data dengan ID 19956
# Berhasil mengambil data untuk ID 19957
# Gagal mengambil data dengan ID 19958
# Berhasil mengambil data untuk ID 19959
# Gagal mengambil data dengan ID 19960
# Berhasil mengambil data untuk ID 19961
# Gagal mengambil data dengan ID 19962
# Gagal mengambil data dengan ID 19963
# Gagal mengambil data dengan ID 19964
# Berhasil mengambil data untuk ID 19965
# Gagal mengambil data dengan ID 19966
# Gagal mengambil data dengan ID 19967
# Gagal mengambil data dengan ID 19968
# Gagal mengambil data dengan ID 19969
# Gagal mengambil data dengan ID 19970
# Berhasil mengambil data untuk ID 19971
# Gagal mengambil data dengan ID 19972
# Berhasil mengambil data untuk ID 19973
# Gagal mengambil data dengan ID 19974
# Gagal mengambil data dengan ID 19975
# Gagal mengambil data dengan ID 19976
# Berhasil mengambil data untuk ID 19977
# Gagal mengambil data dengan ID 19978
# Gagal mengambil data dengan ID 19979
# Gagal mengambil data dengan ID 19980
# Berhasil mengambil data untuk ID 19981
# Gagal mengambil data dengan ID 19982
# Berhasil mengambil data untuk ID 19983
# Gagal mengambil data dengan ID 19984
# Berhasil mengambil data untuk ID 19985
# Gagal mengambil data dengan ID 19986
# Berhasil mengambil data untuk ID 19987
# Gagal mengambil data dengan ID 19988
# Berhasil mengambil data untuk ID 19989
# Gagal mengambil data dengan ID 19990
# Berhasil mengambil data untuk ID 19991
# Gagal mengambil data dengan ID 19992
# Berhasil mengambil data untuk ID 19993
# Gagal mengambil data dengan ID 19994
# Berhasil mengambil data untuk ID 19995
# Gagal mengambil data dengan ID 19996
# Berhasil mengambil data untuk ID 19997
# Gagal mengambil data dengan ID 19998
# Berhasil mengambil data untuk ID 19999
# Gagal mengambil data dengan ID 20000
# Berhasil mengambil data untuk ID 20001
# Gagal mengambil data dengan ID 20002
# Berhasil mengambil data untuk ID 20003
# Gagal mengambil data dengan ID 20004
# Berhasil mengambil data untuk ID 20005
# Gagal mengambil data dengan ID 20006
# Berhasil mengambil data untuk ID 20007
# Gagal mengambil data dengan ID 20008
# Berhasil mengambil data untuk ID 20009
# Gagal mengambil data dengan ID 20010
# Gagal mengambil data dengan ID 20011
# Gagal mengambil data dengan ID 20012
# Gagal mengambil data dengan ID 20013
# Gagal mengambil data dengan ID 20014
# Gagal mengambil data dengan ID 20015
# Gagal mengambil data dengan ID 20016
# Gagal mengambil data dengan ID 20017
# Gagal mengambil data dengan ID 20018
# Gagal mengambil data dengan ID 20019
# Gagal mengambil data dengan ID 20020
# Berhasil mengambil data untuk ID 20021
# Gagal mengambil data dengan ID 20022
# Berhasil mengambil data untuk ID 20023
# Gagal mengambil data dengan ID 20024
# Berhasil mengambil data untuk ID 20025
# Gagal mengambil data dengan ID 20026
# Berhasil mengambil data untuk ID 20027
# Gagal mengambil data dengan ID 20028
# Gagal mengambil data dengan ID 20029
# Gagal mengambil data dengan ID 20030
# Berhasil mengambil data untuk ID 20031
# Gagal mengambil data dengan ID 20032
# Berhasil mengambil data untuk ID 20033
# Gagal mengambil data dengan ID 20034
# Berhasil mengambil data untuk ID 20035
# Gagal mengambil data dengan ID 20036
# Gagal mengambil data dengan ID 20037
# Gagal mengambil data dengan ID 20038
# Berhasil mengambil data untuk ID 20039
# Gagal mengambil data dengan ID 20040
# Gagal mengambil data dengan ID 20041
# Gagal mengambil data dengan ID 20042
# Gagal mengambil data dengan ID 20043
# Gagal mengambil data dengan ID 20044
# Berhasil mengambil data untuk ID 20045
# Gagal mengambil data dengan ID 20046
# Berhasil mengambil data untuk ID 20047
# Gagal mengambil data dengan ID 20048
# Gagal mengambil data dengan ID 20049
# Gagal mengambil data dengan ID 20050
# Gagal mengambil data dengan ID 20051
# Gagal mengambil data dengan ID 20052
# Berhasil mengambil data untuk ID 20053
# Gagal mengambil data dengan ID 20054
# Gagal mengambil data dengan ID 20055
# Gagal mengambil data dengan ID 20056
# Berhasil mengambil data untuk ID 20057
# Gagal mengambil data dengan ID 20058
# Gagal mengambil data dengan ID 20059
# Gagal mengambil data dengan ID 20060
# Gagal mengambil data dengan ID 20061
# Gagal mengambil data dengan ID 20062
# Gagal mengambil data dengan ID 20063
# Gagal mengambil data dengan ID 20064
# Gagal mengambil data dengan ID 20065
# Gagal mengambil data dengan ID 20066
# Gagal mengambil data dengan ID 20067
# Gagal mengambil data dengan ID 20068
# Gagal mengambil data dengan ID 20069
# Gagal mengambil data dengan ID 20070
# Gagal mengambil data dengan ID 20071
# Gagal mengambil data dengan ID 20072
# Gagal mengambil data dengan ID 20073
# Gagal mengambil data dengan ID 20074
# Berhasil mengambil data untuk ID 20075
# Gagal mengambil data dengan ID 20076
# Berhasil mengambil data untuk ID 20077
# Gagal mengambil data dengan ID 20078
# Berhasil mengambil data untuk ID 20079
# Gagal mengambil data dengan ID 20080
# Berhasil mengambil data untuk ID 20081
# Gagal mengambil data dengan ID 20082
# Berhasil mengambil data untuk ID 20083
# Gagal mengambil data dengan ID 20084
# Berhasil mengambil data untuk ID 20085
# Gagal mengambil data dengan ID 20086
# Berhasil mengambil data untuk ID 20087
# Gagal mengambil data dengan ID 20088
# Gagal mengambil data dengan ID 20089
# Gagal mengambil data dengan ID 20090
# ...
# Gagal mengambil data dengan ID 23384
# Berhasil mengambil data untuk ID 23385
# Gagal mengambil data dengan ID 23386
# Berhasil mengambil data untuk ID 23387
# Gagal mengambil data dengan ID 23388
# Gagal mengambil data dengan ID 23389
# Gagal mengambil data dengan ID 23390
# Gagal mengambil data dengan ID 23391
# Gagal mengambil data dengan ID 23392
# Berhasil mengambil data untuk ID 23393
# Gagal mengambil data dengan ID 23394
# Gagal mengambil data dengan ID 23395
# Gagal mengambil data dengan ID 23396
# Gagal mengambil data dengan ID 23397
# Gagal mengambil data dengan ID 23398
# Gagal mengambil data dengan ID 23399
# Gagal mengambil data dengan ID 23400
# Berhasil mengambil data untuk ID 23401
# Gagal mengambil data dengan ID 23402
# Gagal mengambil data dengan ID 23403
# Gagal mengambil data dengan ID 23404
# Berhasil mengambil data untuk ID 23405
# Gagal mengambil data dengan ID 23406
# Berhasil mengambil data untuk ID 23407
# Gagal mengambil data dengan ID 23408
# Berhasil mengambil data untuk ID 23409
# Gagal mengambil data dengan ID 23410
# Gagal mengambil data dengan ID 23411
# Gagal mengambil data dengan ID 23412
# Gagal mengambil data dengan ID 23413
# Gagal mengambil data dengan ID 23414
# Gagal mengambil data dengan ID 23415
# Gagal mengambil data dengan ID 23416
# Gagal mengambil data dengan ID 23417
# Gagal mengambil data dengan ID 23418
# Gagal mengambil data dengan ID 23419
# Gagal mengambil data dengan ID 23420
# Berhasil mengambil data untuk ID 23421
# Gagal mengambil data dengan ID 23422
# Berhasil mengambil data untuk ID 23423
# Gagal mengambil data dengan ID 23424
# Berhasil mengambil data untuk ID 23425
# Gagal mengambil data dengan ID 23426
# Berhasil mengambil data untuk ID 23427
# Gagal mengambil data dengan ID 23428
# Gagal mengambil data dengan ID 23429
# Gagal mengambil data dengan ID 23430
# Gagal mengambil data dengan ID 23431
# Gagal mengambil data dengan ID 23432
# Berhasil mengambil data untuk ID 23433
# Gagal mengambil data dengan ID 23434
# Gagal mengambil data dengan ID 23435
# Gagal mengambil data dengan ID 23436
# Gagal mengambil data dengan ID 23437
# Gagal mengambil data dengan ID 23438
# Berhasil mengambil data untuk ID 23439
# Gagal mengambil data dengan ID 23440
# Berhasil mengambil data untuk ID 23441
# Gagal mengambil data dengan ID 23442
# Gagal mengambil data dengan ID 23443
# Gagal mengambil data dengan ID 23444
# Gagal mengambil data dengan ID 23445
# Gagal mengambil data dengan ID 23446
# Berhasil mengambil data untuk ID 23447
# Gagal mengambil data dengan ID 23448
# Gagal mengambil data dengan ID 23449
# Gagal mengambil data dengan ID 23450
# Gagal mengambil data dengan ID 23451
# Gagal mengambil data dengan ID 23452
# Gagal mengambil data dengan ID 23453
# Gagal mengambil data dengan ID 23454
# Gagal mengambil data dengan ID 23455
# Gagal mengambil data dengan ID 23456
# Gagal mengambil data dengan ID 23457
# Gagal mengambil data dengan ID 23458
# Berhasil mengambil data untuk ID 23459
# Gagal mengambil data dengan ID 23460
# Gagal mengambil data dengan ID 23461
# Gagal mengambil data dengan ID 23462
# Gagal mengambil data dengan ID 23463
# Gagal mengambil data dengan ID 23464
# Gagal mengambil data dengan ID 23465
# Gagal mengambil data dengan ID 23466
# Gagal mengambil data dengan ID 23467
# Gagal mengambil data dengan ID 23468
# Gagal mengambil data dengan ID 23469
# Gagal mengambil data dengan ID 23470
# Gagal mengambil data dengan ID 23471
# Gagal mengambil data dengan ID 23472
# Gagal mengambil data dengan ID 23473
# Gagal mengambil data dengan ID 23474
# Berhasil mengambil data untuk ID 23475
# Gagal mengambil data dengan ID 23476
# Berhasil mengambil data untuk ID 23477
# Gagal mengambil data dengan ID 23478
# Berhasil mengambil data untuk ID 23479
# Gagal mengambil data dengan ID 23480
# Gagal mengambil data dengan ID 23481
# Gagal mengambil data dengan ID 23482
# Berhasil mengambil data untuk ID 23483
# Gagal mengambil data dengan ID 23484
# Gagal mengambil data dengan ID 23485
# Gagal mengambil data dengan ID 23486
# Berhasil mengambil data untuk ID 23487
# Gagal mengambil data dengan ID 23488
# Gagal mengambil data dengan ID 23489
# Gagal mengambil data dengan ID 23490
# Gagal mengambil data dengan ID 23491
# Gagal mengambil data dengan ID 23492
# Gagal mengambil data dengan ID 23493
# Gagal mengambil data dengan ID 23494
# Gagal mengambil data dengan ID 23495
# Gagal mengambil data dengan ID 23496
# Gagal mengambil data dengan ID 23497
# Gagal mengambil data dengan ID 23498
# Berhasil mengambil data untuk ID 23499
# Gagal mengambil data dengan ID 23500
# Gagal mengambil data dengan ID 23501
# Gagal mengambil data dengan ID 23502
# Gagal mengambil data dengan ID 23503
# Gagal mengambil data dengan ID 23504
# Gagal mengambil data dengan ID 23505
# Gagal mengambil data dengan ID 23506
# Gagal mengambil data dengan ID 23507
# Gagal mengambil data dengan ID 23508
# Gagal mengambil data dengan ID 23509
# Gagal mengambil data dengan ID 23510
# Berhasil mengambil data untuk ID 23511
# Gagal mengambil data dengan ID 23512
# Gagal mengambil data dengan ID 23513
# Gagal mengambil data dengan ID 23514
# Berhasil mengambil data untuk ID 23515
# Gagal mengambil data dengan ID 23516
# Berhasil mengambil data untuk ID 23517
# Gagal mengambil data dengan ID 23518
# Berhasil mengambil data untuk ID 23519
# Gagal mengambil data dengan ID 23520
# Gagal mengambil data dengan ID 23521
# Gagal mengambil data dengan ID 23522
# Berhasil mengambil data untuk ID 23523
# Gagal mengambil data dengan ID 23524
# Gagal mengambil data dengan ID 23525
# Gagal mengambil data dengan ID 23526
# Gagal mengambil data dengan ID 23527
# Gagal mengambil data dengan ID 23528
# Gagal mengambil data dengan ID 23529
# Gagal mengambil data dengan ID 23530
# Gagal mengambil data dengan ID 23531
# Gagal mengambil data dengan ID 23532
# Gagal mengambil data dengan ID 23533
# Gagal mengambil data dengan ID 23534
# Gagal mengambil data dengan ID 23535
# Gagal mengambil data dengan ID 23536
# Berhasil mengambil data untuk ID 23537
# Gagal mengambil data dengan ID 23538
# Berhasil mengambil data untuk ID 23539
# Gagal mengambil data dengan ID 23540
# Gagal mengambil data dengan ID 23541
# Gagal mengambil data dengan ID 23542
# Gagal mengambil data dengan ID 23543
# Gagal mengambil data dengan ID 23544
# Gagal mengambil data dengan ID 23545
# Gagal mengambil data dengan ID 23546
# Gagal mengambil data dengan ID 23547
# Gagal mengambil data dengan ID 23548
# Gagal mengambil data dengan ID 23549
# Gagal mengambil data dengan ID 23550
# Berhasil mengambil data untuk ID 23551
# Gagal mengambil data dengan ID 23552
# Gagal mengambil data dengan ID 23553
# Gagal mengambil data dengan ID 23554
# Berhasil mengambil data untuk ID 23555
# Gagal mengambil data dengan ID 23556
# Gagal mengambil data dengan ID 23557
# Gagal mengambil data dengan ID 23558
# Gagal mengambil data dengan ID 23559
# Gagal mengambil data dengan ID 23560
# Gagal mengambil data dengan ID 23561
# Gagal mengambil data dengan ID 23562
# Gagal mengambil data dengan ID 23563
# Gagal mengambil data dengan ID 23564
# Gagal mengambil data dengan ID 23565
# Gagal mengambil data dengan ID 23566
# Gagal mengambil data dengan ID 23567
# Gagal mengambil data dengan ID 23568
# Berhasil mengambil data untuk ID 23569
# Gagal mengambil data dengan ID 23570
# Gagal mengambil data dengan ID 23571
# Gagal mengambil data dengan ID 23572
# Gagal mengambil data dengan ID 23573
# Gagal mengambil data dengan ID 23574
# Berhasil mengambil data untuk ID 23575
# Gagal mengambil data dengan ID 23576
# Gagal mengambil data dengan ID 23577
# Gagal mengambil data dengan ID 23578
# Berhasil mengambil data untuk ID 23579
# Gagal mengambil data dengan ID 23580
# Berhasil mengambil data untuk ID 23581
# Gagal mengambil data dengan ID 23582
# Berhasil mengambil data untuk ID 23583
# Gagal mengambil data dengan ID 23584
# Berhasil mengambil data untuk ID 23585
# Gagal mengambil data dengan ID 23586
# Berhasil mengambil data untuk ID 23587
# Gagal mengambil data dengan ID 23588
# Gagal mengambil data dengan ID 23589
# Gagal mengambil data dengan ID 23590
# Gagal mengambil data dengan ID 23591
# Gagal mengambil data dengan ID 23592
# Berhasil mengambil data untuk ID 23593
# Gagal mengambil data dengan ID 23594
# Berhasil mengambil data untuk ID 23595
# Gagal mengambil data dengan ID 23596
# Berhasil mengambil data untuk ID 23597
# Gagal mengambil data dengan ID 23598
# Gagal mengambil data dengan ID 23599
# Gagal mengambil data dengan ID 23600
# Gagal mengambil data dengan ID 23601
# Gagal mengambil data dengan ID 23602
# Gagal mengambil data dengan ID 23603
# Gagal mengambil data dengan ID 23604
# Berhasil mengambil data untuk ID 23605
# Gagal mengambil data dengan ID 23606
# Berhasil mengambil data untuk ID 23607
# Gagal mengambil data dengan ID 23608
# Berhasil mengambil data untuk ID 23609
# Gagal mengambil data dengan ID 23610
# Berhasil mengambil data untuk ID 23611
# Gagal mengambil data dengan ID 23612
# Berhasil mengambil data untuk ID 23613
# Gagal mengambil data dengan ID 23614
# Berhasil mengambil data untuk ID 23615
# Gagal mengambil data dengan ID 23616
# Berhasil mengambil data untuk ID 23617
# Gagal mengambil data dengan ID 23618
# Berhasil mengambil data untuk ID 23619
# Gagal mengambil data dengan ID 23620
# Berhasil mengambil data untuk ID 23621
# Gagal mengambil data dengan ID 23622
# Berhasil mengambil data untuk ID 23623
# Gagal mengambil data dengan ID 23624
# Gagal mengambil data dengan ID 23625
# Gagal mengambil data dengan ID 23626
# Berhasil mengambil data untuk ID 23627
# Gagal mengambil data dengan ID 23628
# Gagal mengambil data dengan ID 23629
# Gagal mengambil data dengan ID 23630
# Gagal mengambil data dengan ID 23631
# Gagal mengambil data dengan ID 23632
# Berhasil mengambil data untuk ID 23633
# Gagal mengambil data dengan ID 23634
# Berhasil mengambil data untuk ID 23635
# Gagal mengambil data dengan ID 23636
# Berhasil mengambil data untuk ID 23637
# Gagal mengambil data dengan ID 23638
# Berhasil mengambil data untuk ID 23639
# Gagal mengambil data dengan ID 23640
# Berhasil mengambil data untuk ID 23641
# Gagal mengambil data dengan ID 23642
# Berhasil mengambil data untuk ID 23643
# Gagal mengambil data dengan ID 23644
# Berhasil mengambil data untuk ID 23645
# Gagal mengambil data dengan ID 23646
# Berhasil mengambil data untuk ID 23647
# Gagal mengambil data dengan ID 23648
# Gagal mengambil data dengan ID 23649
# Gagal mengambil data dengan ID 23650
# Berhasil mengambil data untuk ID 23651
# Gagal mengambil data dengan ID 23652
# Gagal mengambil data dengan ID 23653
# Gagal mengambil data dengan ID 23654
# Gagal mengambil data dengan ID 23655
# Gagal mengambil data dengan ID 23656
# Gagal mengambil data dengan ID 23657
# Gagal mengambil data dengan ID 23658
# Berhasil mengambil data untuk ID 23659
# Gagal mengambil data dengan ID 23660
# Berhasil mengambil data untuk ID 23661
# Gagal mengambil data dengan ID 23662
# Gagal mengambil data dengan ID 23663
# Gagal mengambil data dengan ID 23664
# Berhasil mengambil data untuk ID 23665
# Gagal mengambil data dengan ID 23666
# Gagal mengambil data dengan ID 23667
# Gagal mengambil data dengan ID 23668
# Gagal mengambil data dengan ID 23669
# Gagal mengambil data dengan ID 23670
# Gagal mengambil data dengan ID 23671
# Gagal mengambil data dengan ID 23672
# Berhasil mengambil data untuk ID 23673
# Gagal mengambil data dengan ID 23674
# Berhasil mengambil data untuk ID 23675
# Gagal mengambil data dengan ID 23676
# Berhasil mengambil data untuk ID 23677
# Gagal mengambil data dengan ID 23678
# Berhasil mengambil data untuk ID 23679
# Gagal mengambil data dengan ID 23680
# Gagal mengambil data dengan ID 23681
# Gagal mengambil data dengan ID 23682
# Gagal mengambil data dengan ID 23683
# Gagal mengambil data dengan ID 23684
# Gagal mengambil data dengan ID 23685
# Gagal mengambil data dengan ID 23686
# Gagal mengambil data dengan ID 23687
# Gagal mengambil data dengan ID 23688
# Gagal mengambil data dengan ID 23689
# Gagal mengambil data dengan ID 23690
# Gagal mengambil data dengan ID 23691
# Gagal mengambil data dengan ID 23692
# Gagal mengambil data dengan ID 23693
# Gagal mengambil data dengan ID 23694
# Gagal mengambil data dengan ID 23695
# Gagal mengambil data dengan ID 23696
# Berhasil mengambil data untuk ID 23697
# Gagal mengambil data dengan ID 23698
# Berhasil mengambil data untuk ID 23699
# Gagal mengambil data dengan ID 23700
# Berhasil mengambil data untuk ID 23701
# Gagal mengambil data dengan ID 23702
# Berhasil mengambil data untuk ID 23703
# Gagal mengambil data dengan ID 23704
# Gagal mengambil data dengan ID 23705
# Gagal mengambil data dengan ID 23706
# Berhasil mengambil data untuk ID 23707
# Gagal mengambil data dengan ID 23708
# Berhasil mengambil data untuk ID 23709
# Gagal mengambil data dengan ID 23710
# Berhasil mengambil data untuk ID 23711
# Gagal mengambil data dengan ID 23712
# Berhasil mengambil data untuk ID 23713
# Gagal mengambil data dengan ID 23714
# Gagal mengambil data dengan ID 23715
# Gagal mengambil data dengan ID 23716
# Gagal mengambil data dengan ID 23717
# Gagal mengambil data dengan ID 23718
# Berhasil mengambil data untuk ID 23719
# Gagal mengambil data dengan ID 23720
# Berhasil mengambil data untuk ID 23721
# Gagal mengambil data dengan ID 23722
# Berhasil mengambil data untuk ID 23723
# Gagal mengambil data dengan ID 23724
# Berhasil mengambil data untuk ID 23725
# Gagal mengambil data dengan ID 23726
# Berhasil mengambil data untuk ID 23727
# Gagal mengambil data dengan ID 23728
# Berhasil mengambil data untuk ID 23729
# Gagal mengambil data dengan ID 23730
# Berhasil mengambil data untuk ID 23731
# Gagal mengambil data dengan ID 23732
# Berhasil mengambil data untuk ID 23733
# Gagal mengambil data dengan ID 23734
# Berhasil mengambil data untuk ID 23735
# Gagal mengambil data dengan ID 23736
# Berhasil mengambil data untuk ID 23737
# Gagal mengambil data dengan ID 23738
# Berhasil mengambil data untuk ID 23739
# Gagal mengambil data dengan ID 23740
# Berhasil mengambil data untuk ID 23741
# Gagal mengambil data dengan ID 23742
# Gagal mengambil data dengan ID 23743
# Gagal mengambil data dengan ID 23744
# Gagal mengambil data dengan ID 23745
# Gagal mengambil data dengan ID 23746
# Gagal mengambil data dengan ID 23747
# Gagal mengambil data dengan ID 23748
# Gagal mengambil data dengan ID 23749
# Gagal mengambil data dengan ID 23750
# Gagal mengambil data dengan ID 23751
# Gagal mengambil data dengan ID 23752
# Berhasil mengambil data untuk ID 23753
# Gagal mengambil data dengan ID 23754
# Berhasil mengambil data untuk ID 23755
# Gagal mengambil data dengan ID 23756
# Gagal mengambil data dengan ID 23757
# Gagal mengambil data dengan ID 23758
# Berhasil mengambil data untuk ID 23759
# Gagal mengambil data dengan ID 23760
# Berhasil mengambil data untuk ID 23761
# Gagal mengambil data dengan ID 23762
# Berhasil mengambil data untuk ID 23763
# Gagal mengambil data dengan ID 23764
# Berhasil mengambil data untuk ID 23765
# Gagal mengambil data dengan ID 23766
# Berhasil mengambil data untuk ID 23767
# Gagal mengambil data dengan ID 23768
# Berhasil mengambil data untuk ID 23769
# Gagal mengambil data dengan ID 23770
# Gagal mengambil data dengan ID 23771
# Gagal mengambil data dengan ID 23772
# Gagal mengambil data dengan ID 23773
# Gagal mengambil data dengan ID 23774
# Berhasil mengambil data untuk ID 23775
# Gagal mengambil data dengan ID 23776
# Berhasil mengambil data untuk ID 23777
# Gagal mengambil data dengan ID 23778
# Berhasil mengambil data untuk ID 23779
# Gagal mengambil data dengan ID 23780
# Berhasil mengambil data untuk ID 23781
# Gagal mengambil data dengan ID 23782
# Gagal mengambil data dengan ID 23783
# Gagal mengambil data dengan ID 23784
# Gagal mengambil data dengan ID 23785
# Gagal mengambil data dengan ID 23786
# Berhasil mengambil data untuk ID 23787
# Gagal mengambil data dengan ID 23788
# Gagal mengambil data dengan ID 23789
# Gagal mengambil data dengan ID 23790
# Gagal mengambil data dengan ID 23791
# Gagal mengambil data dengan ID 23792
# Gagal mengambil data dengan ID 23793
# Gagal mengambil data dengan ID 23794
# Gagal mengambil data dengan ID 23795
# Gagal mengambil data dengan ID 23796
# Gagal mengambil data dengan ID 23797
# Gagal mengambil data dengan ID 23798
# Berhasil mengambil data untuk ID 23799
# Gagal mengambil data dengan ID 23800
# Berhasil mengambil data untuk ID 23801
# Gagal mengambil data dengan ID 23802
# Gagal mengambil data dengan ID 23803
# Gagal mengambil data dengan ID 23804
# Gagal mengambil data dengan ID 23805
# Gagal mengambil data dengan ID 23806
# Gagal mengambil data dengan ID 23807
# Gagal mengambil data dengan ID 23808
# Gagal mengambil data dengan ID 23809
