# %% [markdown]
# ## Scrape the Jikan Database

# %%
import requests
import json

api_url = 'https://api.jikan.moe/v4'

def scrape_page(endpoint, page, file_path):
    response = requests.get(api_url + endpoint + f'?page={page}')
    response.raise_for_status()
    data = response.json()
    with open(file_path, 'w') as f:
        json.dump(data['data'], f, indent=4)

# %%
import datetime
import tqdm
import time
import os

wait = 1.2 # seconds, with 1.15 crashed

def scrape_jikan_db(database):

    directory_path = f'data/raw/{database}'
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)

    last_page = requests.get(api_url + '/' + database).json()['pagination']['last_visible_page']
    length = len(str(last_page))

    print('Started:', datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

    for page in tqdm.trange(1, last_page + 1):
        start = time.perf_counter()
        scrape_page('/' + database, page, directory_path + f'/page{str(page).zfill(length)}.json')
        end = time.perf_counter()
        time.sleep(max(0, start + wait - end))

    print('Finished:', datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# %% [markdown]
# ## Merge Files

# %%
import shutil

def merge_files(database):

    directory_path = f'data/raw/{database}'

    data = []
    for file_name in tqdm.tqdm(os.listdir(directory_path)):
        file_path = os.path.join(directory_path, file_name)
        with open(file_path, 'r') as f:
            file = json.load(f)
        data.extend(file)

    with open(f'data/raw/{database}.json', 'w') as f:
        json.dump(data, f, indent=4)

    shutil.rmtree(directory_path)

# %% [markdown]
# ## Actual Scraping

# %% [markdown]
# ### Anime

# %%
merge_files('anime')
# Out:
# 100%|██████████| 1070/1070 [00:03<00:00, 348.37it/s]

# %%
import pandas as pd
import numpy as np

anime = pd.read_json('/content/data/raw/anime.json')

# Drop Duplicates
old_size = anime.shape[0]
anime = anime.drop_duplicates(subset=['mal_id']).reset_index(drop=True)
print('Duplicates:', old_size - anime.shape[0])

# Remove useless columns (airing column = Currently Airing status, explicit_genres is void)
assert all(anime['airing'] == (anime['status']=='Currently Airing'))
assert all(anime.explicit_genres.astype('str')=='[]')
anime.drop(columns=['airing', 'explicit_genres'], inplace=True)

# Avoid 'Unknown' and 'None' strings
for col in ['type', 'source', 'duration']:
    anime[col] = anime[col].replace('Unknown', np.nan)
anime['rating'] = anime['rating'].replace('None', np.nan)

# Avoid unnecessary floats
for col in ['scored_by', 'episodes', 'year']:
    anime[col] = anime[col].astype('Int64')

# Simplify aired dates
anime['aired_from'] = pd.to_datetime(anime['aired'].str['from']).dt.date
anime['aired_to'] = pd.to_datetime(anime['aired'].str['to']).dt.date
anime.drop(columns=['aired'], inplace=True)

# Use popularity=0 to detect 'pending approval' animes
anime['pending_approval'] = anime['popularity'] == 0

#  Drop rank and popularity, as they sort equal score / members alphabetically...
anime.drop(columns=['rank', 'popularity'], inplace=True)

# Missing synopsis and background
old_default_synopsis = 'No synopsis has been added for this series yet. Click here to update this information.'
anime['synopsis'] = anime['synopsis'].replace('', np.nan).replace(old_default_synopsis, np.nan)
anime['background'] = anime['background'].replace('', np.nan)

# season and year should be for all, premiered only in TV shows
anime.rename(columns={'season': 'premiered_season', 'year': 'premiered_year'}, inplace=True)

# Simplify broadcast
anime['broadcast_day'] = anime['broadcast'].str['day']
anime['broadcast_time'] = anime['broadcast'].str['time']
anime.drop(columns=['broadcast'], inplace=True)

# Only keep names
for col in ['producers', 'licensors', 'studios', 'genres', 'themes', 'demographics']:
    anime[col] = anime[col].apply(lambda x: [dic['name'] for dic in x] if not x is np.nan else [])

# Replace old Themes names
old_themes_names = {'Police': 'Detective', 'Cars': 'Racing', 'Demons': 'Mythology', 'Game': 'Strategy Game'}
anime['themes'] = anime['themes'].apply(lambda x: [t if t not in old_themes_names else old_themes_names[t] for t in x])

# R18+ definition by MAL (not ranked)
anime['nsfw'] = anime['genres'].apply(lambda x: 'Hentai' in x or 'Erotica' in x)

# Simplify trailer. Pictures: default.jpg and prefixs sd, mq, hq, maxres
anime['trailer_url'] = anime['trailer'].str['url']
anime.drop(columns=['trailer'], inplace=True)

# Simplify main_picture, delete default. Options: .jpg, t.jpg, l.jpg, .webp, t.webp, l.webp
default_image = 'https://cdn.myanimelist.net/img/sp/icon/apple-touch-icon-256.png'
anime['main_picture'] = anime['images'].str['jpg'].str['image_url'].replace(default_image, np.nan)
anime.drop(columns=['images'], inplace=True)

# Better order
order = ['mal_id', 'title', 'type', 'score', 'scored_by', 'status', 'episodes', 'aired_from', 'aired_to', 'source',
         'members', 'favorites', 'duration', 'rating', 'nsfw', 'pending_approval', 'premiered_season', 'premiered_year',
         'broadcast_day', 'broadcast_time', 'genres', 'themes', 'demographics', 'studios', 'producers', 'licensors',
         'synopsis', 'background', 'main_picture', 'url', 'trailer_url', 'title_english', 'title_japanese', 'title_synonyms']

anime = anime[order]

# Sort by Top Anime
anime['tmp'] = anime['score'].rank(ascending=False) + anime['scored_by'].rank(ascending=False)
anime = anime.sort_values('tmp').reset_index(drop=True)
anime.drop(columns=['tmp'], inplace=True)

# Save as csv
anime.to_csv('data/anime.csv', index=False)

print(anime.shape)

pd.options.display.max_columns = None
anime.head(1)
# Out:
# Duplicates: 113
# <ipython-input-6-e98f1247a237>:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime['tmp'] = anime['score'].rank(ascending=False) + anime['scored_by'].rank(ascending=False)
# (26633, 34)
#    mal_id                             title type  score  scored_by  \
# 0    5114  Fullmetal Alchemist: Brotherhood   TV   9.09    2125584
#
#             status  episodes  aired_from    aired_to source  members  \
# 0  Finished Airing        64  2009-04-05  2010-07-04  Manga  3353933
#
#    favorites       duration                          rating   nsfw  \
# 0     226439  24 min per ep  R - 17+ (violence & profanity)  False
#
#    pending_approval premiered_season  premiered_year broadcast_day  \
# 0             False           spring            2009       Sundays
#
#   broadcast_time                               genres      themes  \
# 0          17:00  [Action, Adventure, Drama, Fantasy]  [Military]
#
#   demographics  studios                                          producers  \
# 0    [Shounen]  [Bones]  [Aniplex, Square Enix, Mainichi Broadcasting S...
#
#                           licensors  \
# 0  [Funimation, Aniplex of America]
#
#                                             synopsis background  \
# 0  After a horrific alchemy experiment goes wrong...        NaN
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
#
#                                       title_synonyms
# 0  [Hagane no Renkinjutsushi: Fullmetal Alchemist...

# %%
import pandas as pd
import ast

anime = pd.read_csv('/content/data/anime.csv')

for col in ['scored_by', 'episodes', 'premiered_year']:
    anime[col] = anime[col].astype('Int64')

for col in ['aired_from', 'aired_to']:
    anime[col] = pd.to_datetime(anime[col]).dt.date

anime['broadcast_time'] = pd.to_datetime(anime['broadcast_time']).dt.time

for col in ['genres', 'themes', 'demographics', 'studios', 'producers', 'licensors', 'title_synonyms']:
    anime[col] = anime[col].apply(ast.literal_eval)
# Out:
# <ipython-input-7-62057a149a80>:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   anime['broadcast_time'] = pd.to_datetime(anime['broadcast_time']).dt.time
#    mal_id                             title type  score  scored_by  \
# 0    5114  Fullmetal Alchemist: Brotherhood   TV   9.09    2125584
#
#             status  episodes  aired_from    aired_to source  members  \
# 0  Finished Airing        64  2009-04-05  2010-07-04  Manga  3353933
#
#    favorites       duration                          rating   nsfw  \
# 0     226439  24 min per ep  R - 17+ (violence & profanity)  False
#
#    pending_approval premiered_season  premiered_year broadcast_day  \
# 0             False           spring            2009       Sundays
#
#   broadcast_time                               genres      themes  \
# 0       17:00:00  [Action, Adventure, Drama, Fantasy]  [Military]
#
#   demographics  studios                                          producers  \
# 0    [Shounen]  [Bones]  [Aniplex, Square Enix, Mainichi Broadcasting S...
#
#                           licensors  \
# 0  [Funimation, Aniplex of America]
#
#                                             synopsis background  \
# 0  After a horrific alchemy experiment goes wrong...        NaN
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
#
#                                       title_synonyms
# 0  [Hagane no Renkinjutsushi: Fullmetal Alchemist...

# %%
anime
# Out:
#        mal_id                                              title   type  \
# 0        5114                   Fullmetal Alchemist: Brotherhood     TV
# 1       11061                             Hunter x Hunter (2011)     TV
# 2       38524                 Shingeki no Kyojin Season 3 Part 2     TV
# 3        9253                                        Steins;Gate     TV
# 4       28851                                     Koe no Katachi  Movie
# ...       ...                                                ...    ...
# 26628   41458                           Origami Ninja Koyankinte     TV
# 26629   41460  Kore ga Masakano Are deshita: Wakamono no Shou...    ONA
# 26630   41470                          Micchiri Wanko! Animation     TV
# 26631   41475                                 Hulu Xiao Jin Gang    OVA
# 26632    9606                                   Kaba no Potomasu  Movie
#
#        score  scored_by            status  episodes  aired_from    aired_to  \
# 0       9.09    2125584   Finished Airing        64  2009-04-05  2010-07-04
# 1       9.03    1768158   Finished Airing       148  2011-10-02  2014-09-24
# 2       9.05    1592959   Finished Airing        10  2019-04-29  2019-07-01
# 3       9.07    1403149   Finished Airing        24  2011-04-06  2011-09-14
# 4       8.93    1619864   Finished Airing         1  2016-09-17         NaT
# ...      ...        ...               ...       ...         ...         ...
# 26628    NaN       <NA>  Currently Airing      <NA>  2020-04-07         NaT
# 26629    NaN       <NA>   Finished Airing         1  2020-03-12         NaT
# 26630    NaN       <NA>   Finished Airing        24  2020-04-01  2020-09-09
# 26631    NaN       <NA>   Finished Airing         6  1989-01-01  1991-01-01
# 26632    NaN       <NA>   Finished Airing         1  1988-09-01         NaT
#
#              source  members  favorites       duration  \
# 0             Manga  3353933     226439  24 min per ep
# 1             Manga  2841616     210917  23 min per ep
# 2             Manga  2285318      58771  23 min per ep
# 3      Visual novel  2570007     189959  24 min per ep
# 4             Manga  2337848      88035    2 hr 10 min
# ...             ...      ...        ...            ...
# 26628           NaN      334          0            NaN
# 26629      Original      285          0          3 min
# 26630         Other      881          1   1 min per ep
# 26631      Original      209          1  18 min per ep
# 26632           NaN      266          1         25 min
#
#                                rating   nsfw  pending_approval  \
# 0      R - 17+ (violence & profanity)  False             False
# 1           PG-13 - Teens 13 or older  False             False
# 2      R - 17+ (violence & profanity)  False             False
# 3           PG-13 - Teens 13 or older  False             False
# 4           PG-13 - Teens 13 or older  False             False
# ...                               ...    ...               ...
# 26628                   PG - Children  False             False
# 26629                    G - All Ages  False             False
# 26630                    G - All Ages  False             False
# 26631                   PG - Children  False             False
# 26632                   PG - Children  False             False
#
#       premiered_season  premiered_year broadcast_day broadcast_time  \
# 0               spring            2009       Sundays       17:00:00
# 1                 fall            2011       Sundays       10:55:00
# 2               spring            2019       Mondays       00:10:00
# 3               spring            2011    Wednesdays       02:05:00
# 4                  NaN            <NA>           NaN            NaT
# ...                ...             ...           ...            ...
# 26628           spring            2020      Tuesdays       07:30:00
# 26629              NaN            <NA>           NaN            NaT
# 26630           spring            2020    Wednesdays       07:30:00
# 26631              NaN            <NA>           NaN            NaT
# 26632              NaN            <NA>           NaN            NaT
#
#                                     genres                        themes  \
# 0      [Action, Adventure, Drama, Fantasy]                    [Military]
# 1             [Action, Adventure, Fantasy]                            []
# 2                [Action, Drama, Suspense]    [Gore, Military, Survival]
# 3                [Drama, Sci-Fi, Suspense]  [Psychological, Time Travel]
# 4                   [Award Winning, Drama]            [Romantic Subtext]
# ...                                    ...                           ...
# 26628                             [Comedy]                            []
# 26629                              [Drama]                            []
# 26630                             [Comedy]                            []
# 26631                  [Action, Adventure]                 [Super Power]
# 26632                                   []                            []
#
#       demographics                           studios  \
# 0        [Shounen]                           [Bones]
# 1        [Shounen]                        [Madhouse]
# 2        [Shounen]                      [Wit Studio]
# 3               []                       [White Fox]
# 4        [Shounen]                 [Kyoto Animation]
# ...            ...                               ...
# 26628       [Kids]                      [Directions]
# 26629           []                  [Studio Placebo]
# 26630       [Kids]                      [Charaction]
# 26631       [Kids]  [Shanghai Animation Film Studio]
# 26632       [Kids]                  [Oh! Production]
#
#                                                producers  \
# 0      [Aniplex, Square Enix, Mainichi Broadcasting S...
# 1             [VAP, Nippon Television Network, Shueisha]
# 2      [Production I.G, Dentsu, Mainichi Broadcasting...
# 3      [Frontier Works, Media Factory, Kadokawa Shote...
# 4      [Shochiku, Pony Canyon, Kodansha, ABC Animatio...
# ...                                                  ...
# 26628                                         [TV Tokyo]
# 26629                                                 []
# 26630                                                 []
# 26631                                                 []
# 26632                                                 []
#
#                               licensors  \
# 0      [Funimation, Aniplex of America]
# 1                           [VIZ Media]
# 2                          [Funimation]
# 3                          [Funimation]
# 4              [Eleven Arts, NYAV Post]
# ...                                 ...
# 26628                                []
# 26629                                []
# 26630                                []
# 26631                                []
# 26632                                []
#
#                                                 synopsis  \
# 0      After a horrific alchemy experiment goes wrong...
# 1      Hunters devote themselves to accomplishing haz...
# 2      Seeking to restore humanity's diminishing hope...
# 3      Eccentric scientist Rintarou Okabe has a never...
# 4      As a wild youth, elementary school student Sho...
# ...                                                  ...
# 26628  Koyan, the Origami Ninja, came to Earth from h...
# 26629  The adult age in japan will be reduced from 20...
# 26630                         Spin-off of Micchiri Neko.
# 26631                                                NaN
# 26632  Potomas the Hippo has a secret-he can speak li...
#
#                                               background  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Shingeki no Kyojin Season 3 Part 2 adapts cont...
# 3      Steins;Gate is based on 5pb. and Nitroplus' vi...
# 4      Koe no Katachi won the following awards: Japan...
# ...                                                  ...
# 26628                                                NaN
# 26629                                                NaN
# 26630                                                NaN
# 26631                                                NaN
# 26632                                                NaN
#
#                                             main_picture  \
# 0      https://cdn.myanimelist.net/images/anime/1208/...
# 1      https://cdn.myanimelist.net/images/anime/1337/...
# 2      https://cdn.myanimelist.net/images/anime/1517/...
# 3      https://cdn.myanimelist.net/images/anime/1935/...
# 4      https://cdn.myanimelist.net/images/anime/1122/...
# ...                                                  ...
# 26628  https://cdn.myanimelist.net/images/anime/1860/...
# 26629  https://cdn.myanimelist.net/images/anime/1900/...
# 26630  https://cdn.myanimelist.net/images/anime/1793/...
# 26631  https://cdn.myanimelist.net/images/anime/1298/...
# 26632  https://cdn.myanimelist.net/images/anime/11/26...
#
#                                                      url  \
# 0      https://myanimelist.net/anime/5114/Fullmetal_A...
# 1      https://myanimelist.net/anime/11061/Hunter_x_H...
# 2      https://myanimelist.net/anime/38524/Shingeki_n...
# 3         https://myanimelist.net/anime/9253/Steins_Gate
# 4      https://myanimelist.net/anime/28851/Koe_no_Kat...
# ...                                                  ...
# 26628  https://myanimelist.net/anime/41458/Origami_Ni...
# 26629  https://myanimelist.net/anime/41460/Kore_ga_Ma...
# 26630  https://myanimelist.net/anime/41470/Micchiri_W...
# 26631  https://myanimelist.net/anime/41475/Hulu_Xiao_...
# 26632  https://myanimelist.net/anime/9606/Kaba_no_Pot...
#
#                                        trailer_url  \
# 0      https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1      https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2      https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3      https://www.youtube.com/watch?v=27OZc-ku6is
# 4      https://www.youtube.com/watch?v=XBNWo25izJ8
# ...                                            ...
# 26628                                          NaN
# 26629                                          NaN
# 26630                                          NaN
# 26631                                          NaN
# 26632                                          NaN
#
#                           title_english              title_japanese  \
# 0      Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                       Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2       Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                           Steins;Gate                 STEINS;GATE
# 4                        A Silent Voice                         聲の形
# ...                                 ...                         ...
# 26628                               NaN          おりがみにんじゃ コーヤン＠きんてれ
# 26629                               NaN     コレがまさかのアレでした ～若者の消費者被害～
# 26630                               NaN             みっちりわんこ！あにめ～しょん
# 26631                               NaN                       葫芦小金刚
# 26632                               NaN                     かばのポトマス
#
#                                           title_synonyms
# 0      [Hagane no Renkinjutsushi: Fullmetal Alchemist...
# 1                                           [HxH (2011)]
# 2                                                     []
# 3                                                     []
# 4                                   [The Shape of Voice]
# ...                                                  ...
# 26628                              [Happy Smile ♡ Dream]
# 26629                                                 []
# 26630                                                 []
# 26631  [Diamond Brother, Hulu Brothers 2, Calabash Br...
# 26632                                [Potomas the Hippo]
#
# [26633 rows x 34 columns]
